# %% [markdown]
# # EECS 182, Fall 2026 - Initialization and Optimizers
#
# This exercise now uses the reviewed Fall 2026 homework copy.
#
# [Open the current notebook in Colab](https://colab.research.google.com/github/Berkeley-CS182/cs182fa26_public/blob/main/hw02/code/hw2_optimizer_init.ipynb). Complete and save your work in that notebook.
